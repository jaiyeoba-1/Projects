# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiyeoba-1/Projects/blob/main/Matplotlib_and_Seaborn_on_Telco_Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('Telco-Customer-Churn.csv')

# Display the first few rows to confirm it's loaded correctly
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Average MonthlyCharges over tenure

# %%
# Average MonthlyCharges over tenure
avg_charges = df.groupby('tenure')['MonthlyCharges'].mean()

plt.plot(avg_charges.index, avg_charges.values, color='blue', marker='o')
plt.title("Average Monthly Charges Over Tenure")
plt.xlabel("Tenure (months)")
plt.ylabel("Monthly Charges ($)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Distribution of TotalCharges

# %%
# Convert TotalCharges to numeric (handle missing values if needed)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

sns.histplot(df['TotalCharges'], kde=True, color='green')
plt.title("Distribution of Total Charges")
plt.xlabel("Total Charges ($)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Distribution of customers by InternetService type

# %%
sns.countplot(x='InternetService', data=df, palette='coolwarm')
plt.title("Count of Customers by Internet Service Type")
plt.xlabel("Internet Service Type")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-5-d828e4fcd448>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='InternetService', data=df, palette='coolwarm')

# %% [markdown]
# ### Monthly Charges grouped by Payment Method

# %%
sns.boxplot(x='PaymentMethod', y='MonthlyCharges', data=df, palette='Set2')
plt.title("Monthly Charges by Payment Method")
plt.xticks(rotation=45)
plt.xlabel("Payment Method")
plt.ylabel("Monthly Charges ($)")
plt.show()
# Out:
# <ipython-input-6-7cd023ba9fd9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='PaymentMethod', y='MonthlyCharges', data=df, palette='Set2')

# %% [markdown]
# ### Tenure vs. Monthly Charges, color-coded by Churn

# %%
sns.scatterplot(x='tenure', y='MonthlyCharges', hue='Churn', data=df, palette='husl')
plt.title("Tenure vs Monthly Charges by Churn Status")
plt.xlabel("Tenure (months)")
plt.ylabel("Monthly Charges ($)")
plt.show()

# %% [markdown]
# ### Pair Plot for Tenure, Monthly Charges, and Total Charges

# %%
sns.pairplot(df[['tenure', 'MonthlyCharges', 'TotalCharges']], diag_kind='kde')
plt.suptitle("Pair Plot of Tenure, Monthly Charges, and Total Charges", y=1.02)
plt.show()

# %% [markdown]
# ### Applying Themes and Color Palettes

# %%
# Apply a Seaborn theme
sns.set_theme(style="darkgrid", palette="muted")

# Create a styled bar plot
sns.barplot(x='Contract', y='MonthlyCharges', data=df)
plt.title("Styled Bar Plot of Monthly Charges by Contract Type")
plt.show()
