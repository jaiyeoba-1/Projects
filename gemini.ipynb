# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiyeoba-1/Projects/blob/main/gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai

# Configure Gemini with your API key
genai.configure(api_key="AIzaSyCK2bSBzSpgC2buFCDKJdXRKk0qJPHjgl4")

# Set up model configuration
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config
)

# %%
chat_session = model.start_chat(
  history=[
    {
      "role": "user",
      "parts": [
        "You are a market research analyst specializing in consumer electronics.\\n",
      ],
    }
  ]
)

# %%
# Test different prompts
response1 = chat_session.send_message("What are the key factors customers consider when buying headphones?")
print(response1.text)

response2 = chat_session.send_message("How would you analyze customer feedback about sound quality?")
print(response2.text)
# Out:
# Customers consider a variety of factors when purchasing headphones, and the importance of each factor can vary significantly depending on the individual's needs, budget, and listening habits.  These factors can be broadly categorized as:
#
# **1. Sound Quality:** This is arguably the most important factor for many buyers.  Sub-categories include:
#
# * **Frequency Response:**  The range of frequencies the headphones accurately reproduce (bass, mids, treble).  A balanced response is often preferred, but some users prioritize specific frequencies (e.g., bass-heavy headphones for hip-hop).
# * **Clarity and Detail:** The ability to discern individual instruments and nuances in the music.
# * **Soundstage:** The sense of space and width of the sound.  Open-back headphones generally offer a wider soundstage than closed-back ones.
# * **Distortion:**  Unwanted sounds or artifacts that detract from the audio quality.
#
# **2. Comfort and Fit:**  Long listening sessions require comfortable headphones. This includes:
#
# * **Earcup Design:** Over-ear, on-ear, or in-ear; material (e.g., leather, fabric, silicone); clamping force.
# * **Weight:** Lighter headphones are generally more comfortable for extended use.
# * **Earcup Size:**  Important for over-ear and on-ear headphones to ensure proper fit and pressure.
#
# **3. Features and Functionality:**  Beyond basic sound reproduction, features can be crucial:
#
# * **Noise Cancellation (ANC):**  Reduces ambient noise, particularly important for travel or noisy environments.
# * **Transparency Mode:**  Allows ambient sound to pass through, useful for situational awareness.
# * **Wireless Connectivity:** Bluetooth version and codec (e.g., aptX, AAC) influence connection stability and sound quality.
# * **Microphone Quality:**  Essential for calls and voice assistants.
# * **Battery Life:** Crucial for wireless headphones.
# * **Water Resistance:**  Important for workouts or outdoor use.
# * **Controls:**  Ease of use and accessibility of volume, playback, and call management controls.
#
# **4. Price and Value:**  Budget significantly impacts purchasing decisions. Customers weigh the features and sound quality against the price to determine value.
#
# **5. Brand Reputation and Reviews:**  Customer trust in established brands and positive reviews influence purchasing choices.
#
# **6. Aesthetics and Design:**  Style and appearance are important considerations for some customers, particularly with portable headphones.
#
# **7. Compatibility:**  Ensuring compatibility with devices (e.g., smartphones, laptops, game consoles) is a critical factor.
#
#
# Understanding the relative importance of these factors across different customer segments (e.g., audiophiles, casual listeners, gamers) is crucial for effective market research and product development in the consumer electronics industry.
#
# Analyzing customer feedback about sound quality requires a systematic approach that goes beyond simply counting positive and negative comments.  Here's a breakdown of how I would analyze such feedback:
#
# **1. Data Collection:**
#
# * **Gather feedback from multiple sources:** This includes online reviews (Amazon, Best Buy, dedicated audio forums), social media mentions, customer surveys, and focus groups.  Consider both quantitative (ratings, star reviews) and qualitative (textual reviews, comments) data.
# * **Ensure a representative sample:** The feedback should represent a broad range of users and listening preferences to avoid bias.  Consider demographics, listening habits (music genres, listening environment), and headphone usage scenarios.
#
#
# **2. Data Cleaning and Preparation:**
#
# * **Organize and categorize the data:**  Use spreadsheets or dedicated qualitative data analysis software to organize the feedback.
# * **Clean the data:** Remove irrelevant information, duplicates, and spam.
# * **Translate feedback into consistent language:** Standardize terminology and phrasing for easier analysis.
#
#
# **3. Qualitative Analysis:**
#
# * **Sentiment analysis:** Determine the overall sentiment (positive, negative, neutral) of the reviews. This can be done manually or using sentiment analysis tools.
# * **Thematic analysis:** Identify recurring themes and patterns in the feedback.  This involves coding the data, grouping similar comments together, and identifying key themes related to sound quality.  Examples of themes could be:
#     * **Bass response:**  Too much bass, too little bass, muddy bass, punchy bass, etc.
#     * **Treble response:**  Harsh treble, sibilance, bright treble, detailed treble, etc.
#     * **Midrange clarity:**  Vowel clarity, instrument separation, etc.
#     * **Soundstage:**  Wide soundstage, narrow soundstage, immersive sound, etc.
#     * **Overall balance:**  Balanced sound, warm sound, bright sound, etc.
# * **Detailed review analysis:**  For in-depth understanding, manually review a sample of the reviews to identify nuances and specific issues not captured by automated analysis.
#
#
# **4. Quantitative Analysis:**
#
# * **Frequency distribution of ratings:** Analyze the distribution of star ratings or numerical scores to identify the overall level of satisfaction with the sound quality.
# * **Correlation analysis (if applicable):** If you have data on specific user characteristics (e.g., age, music preference), analyze correlations between these characteristics and their sound quality ratings.
#
#
# **5. Interpretation and Reporting:**
#
# * **Summarize findings:** Create a concise summary of the key findings from both qualitative and quantitative analysis.
# * **Visualizations:** Use charts and graphs (e.g., word clouds, bar charts, pie charts) to present the results effectively.
# * **Identify areas for improvement:** Based on the analysis, pinpoint specific aspects of the sound quality that need improvement (e.g., excessive bass, lack of clarity in the midrange).
# * **Prioritize improvements:** Prioritize improvements based on the severity and frequency of the identified issues and their impact on customer satisfaction.
#
#
# By combining qualitative and quantitative analysis techniques, you can gain a comprehensive understanding of customer perceptions of sound quality, enabling data-driven decisions for product improvement and marketing strategies.  This approach allows for a more nuanced understanding than simply relying on average ratings alone.

# %%
import pandas as pd
import google.generativeai as genai

# Load your dataset
df = pd.read_csv('cleaned_dataset.csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyCK2bSBzSpgC2buFCDKJdXRKk0qJPHjgl4"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
# Select reviews to analyze
reviews = df['content'].head(100).tolist()

# Create your prompt
prompt_message = "Analyze the following reviews and summarize the key insights:"

# Get insights
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# The reviews highlight several key aspects of various portable Bluetooth speakers, allowing for a comparison across brands and models:
#
# **Sound Quality:**  Most reviewers praise the sound quality, especially considering the compact size of the speakers.  Several mention surprisingly good bass for their size, while some note that certain speakers (like the Beats Pill) excel at various genres, while others may be muddier with voices or less suitable for classical music.  JBL speakers frequently receive compliments for their powerful sound and bass, while the Bose SoundLink Flex is lauded for its rich, clear sound and deep bass even outdoors.  The Sony ULT Field 1 is described as having clear and punchy sound, with a noticeable bass boost option. The Soundcore Boom 2 also gets high marks for its clarity and depth of sound, even in noisy environments.
#
# **Portability and Durability:**  Portability is a major selling point across the board.  Many speakers are described as easily fitting in bags or cup holders. Durability is also frequently mentioned, with many reviewers noting their speakers' ability to withstand drops, splashes, dust, and even submersion (for those with IP ratings).  The rugged build of the Bose SoundLink Flex and Sony ULT Field 1 are explicitly praised.
#
# **Features and Functionality:**  Several features are mentioned, including:
#
# * **Battery Life:**  Most speakers boast impressive battery life, with many lasting a full day or more on a single charge.  However, some reviewers note that using features like bass boost or lights can impact battery life.
# * **Water Resistance:**  IP ratings (like IP67) are frequently highlighted as a desirable feature for outdoor use.
# * **Connectivity:**  Bluetooth pairing is generally described as easy and reliable, though some reviewers mention occasional connectivity issues with certain speakers (like the Beats Pill).
# * **Extra Features:**  Some speakers offer additional features like voice activation (though this is often criticized for not being truly hands-free),  EQ adjustments (either via physical buttons or apps), and the ability to pair multiple speakers for stereo sound.  The Sony ULT Field 1's ULT bass boost button and the JBL Flip 6's PartyBoost are examples of these.
# * **Ease of Use:**  Reviewers generally find the speakers easy to set up and use.
#
# **Price and Value:** Reviewers emphasize the value for money offered by many of these speakers, particularly those under $100. However, higher-priced options like the Bose SoundLink Flex are justified by their superior sound quality and features.
#
# **Brand Preferences:**  While various brands are reviewed (Bose, JBL, Sony, Beats, Anker/Soundcore), each receives both praise and criticism.  No single brand emerges as a clear winner, suggesting that the best choice depends on individual needs and preferences.
#
#
# In summary, the reviews point to a highly competitive market for portable Bluetooth speakers, where buyers can find a speaker that meets their needs in terms of sound quality, portability, durability, features, and price, with trade-offs present in each model.  Reading multiple reviews for a specific model before purchasing is recommended.

# %%
df.head()
# Out:
#         review_id  product_id  \
# 0  R34TTAFP8L6LLN  B0D6WB7BV6
# 1   RZM2F3FFLUDL0  B0D6WB7BV6
# 2  R20S61ZXL3M7J3  B0D6WB7BV6
# 3  R1WP53KHLAFXUC  B0D6WB7BV6
# 4  R2SUSKG5E9AHRZ  B0D6WB7BV6
#
#                                                title                 author  \
# 0  5.0 out of 5 stars Price check; Sound quality ...   Gary J and Stephan D
# 1            5.0 out of 5 stars Great little speaker        Amazon Customer
# 2  5.0 out of 5 stars Portable, Powerful, and Bui...  Claudia janeth Jaimes
# 3  5.0 out of 5 stars Works Well in the Garage an...                 InMyHO
# 4         5.0 out of 5 stars Great product from BOSE         Lynne A. Coyle
#
#    rating                                            content  \
# 0       5  I shopped for quite a bit to find this item at...
# 1       5  I love this speaker. It's exactly what I neede...
# 2       5  I’m thoroughly impressed with the Bose SoundLi...
# 3       5  I wasn’t expecting much from something this si...
# 4       5  You can’t go wrong with the BOSE name. I have ...
#
#                                       timestamp                    profile_id  \
# 0  Reviewed in the United States April 26, 2025  AFX2ZUIIXGCBMX26OGNHRTNAQKFA
# 1  Reviewed in the United States April 21, 2025  AFBOWR7MHZULQ4YRPZLQY66EKUUA
# 2  Reviewed in the United States April 14, 2025  AEAITP4PL7NDNRQ5XXOUNM2YJWOQ
# 3     Reviewed in the United States May 3, 2025  AFML75XPURJQZLHSD2VDR7JCCUFQ
# 4     Reviewed in the United States May 5, 2025  AGQQJ3LWDXRT3W7OKJJ6TEB3EEAQ
#
#    is_verified  helpful_count  product_attributes
# 0         True              4    Color: Blue Dusk
# 1         True             10  Color: Alpine Sage
# 2         True             21  Color: Alpine Sage
# 3         True              3    Color: Blue Dusk
# 4         True              4  Color: Alpine Sage

# %%
# Check unique products in your dataset
unique_products = df['product_id'].unique()
print("Products in dataset:")
for product in unique_products:
    print(f"- {product}")
# Out:
# Products in dataset:
# - B0D6WB7BV6
# - B0CXKSCY1G
# - B09GJZKQ3K
# - B0CQ53RVTW
# - B0D4SX9RC6

# %%
# Create a mapping dictionary for product names
# NOTE: CREATE MAPPING FOR YOUR PRODUCTS HERE
product_mapping = {
    "B0D6WB7BV6": {
        "short_name": "Bose SoundLink Flex Speaker",
        "brand": "Bose",
    },
    "B0CXKSCY1G": {
        "short_name": "Sony ULT Field 1",
        "brand": "Sony"
    },
    "B09GJZKQ3K": {
        "short_name": "JBL Flip 6",
        "brand": "JBL"
    },
    "B0CQ53RVTW": {
        "short_name": "Soundcore Boom 2",
        "brand": "Anker"
    },
    "B0D4SX9RC6": {
        "short_name": "Beats Pill",
        "brand": "Beats"
    }
}

# %%
# Function to apply the mapping to your dataset
def clean_product_info(df, mapping):
    # Create new columns using the mapping
    df['short_name'] = df['product_id'].map({k: v['short_name'] for k, v in mapping.items()})
    df['brand'] = df['product_id'].map({k: v['brand'] for k, v in mapping.items()})

    # Handle any products not in mapping
    df['short_name'] = df['short_name'].fillna(df['product_id'])
    df['brand'] = df['brand'].fillna('Unknown')

    return df

# %%
# Clean your dataset
df = clean_product_info(df, product_mapping)

# View the results
print("\\nSample of cleaned data:")
print(df[['product_id', 'short_name', 'brand']].head())
# Out:
# \nSample of cleaned data:
#    product_id                   short_name brand
# 0  B0D6WB7BV6  Bose SoundLink Flex Speaker  Bose
# 1  B0D6WB7BV6  Bose SoundLink Flex Speaker  Bose
# 2  B0D6WB7BV6  Bose SoundLink Flex Speaker  Bose
# 3  B0D6WB7BV6  Bose SoundLink Flex Speaker  Bose
# 4  B0D6WB7BV6  Bose SoundLink Flex Speaker  Bose

# %%
from textblob import TextBlob

def add_sentiment_info(df):
    # Add sentiment scores
    df['sentiment_score'] = df['content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

    # Categorize sentiments
    df['sentiment_category'] = df['sentiment_score'].apply(lambda x:
        'Positive' if x > 0.1
        else 'Negative' if x < -0.1
        else 'Neutral')

    return df

# %%
# Add sentiment information
df = add_sentiment_info(df)

# Quick view of sentiment distribution
print("\\nSentiment Distribution:")
print(df['sentiment_category'].value_counts()*100/len(df))
# Out:
# \nSentiment Distribution:
# sentiment_category
# Positive    100.0
# Name: count, dtype: float64

# %%
def analyze_basic_product(reviews, product_name):
    prompt_message = f"""Analyze these reviews for {product_name}:
    1. What are the top 3 most mentioned features?
    2. What do customers love most about this product?
    3. What are the most common complaints?

    Please provide specific examples from the reviews."""


    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze a single product
product_reviews = df[df['short_name'] == 'Bose SoundLink Flex Speaker']['content'].tolist()[:30]

basic_insights = analyze_basic_product(product_reviews, 'Bose SoundLink Flex Speaker')
print(basic_insights)
# Out:
# Here's an analysis of the Bose SoundLink Flex speaker reviews:
#
# **1. Top 3 Most Mentioned Features:**
#
# 1. **Sound Quality:**  Multiple reviewers highlight the surprisingly good sound quality for its size, mentioning "rich, clear sound," "deep bass," and "great sound quality" even in larger spaces. One reviewer even states it "fills the place with sound," exceeding their expectations.  The unexpected bass response is frequently praised.
#
# 2. **Portability and Durability:** The speaker's compact size, rugged design, and IP67 water and dust resistance are repeatedly mentioned as significant advantages.  Reviewers plan to use it outdoors, camping, traveling, and in harsh environments like garages, confident in its ability to withstand drops and exposure to the elements.
#
# 3. **Battery Life:**  Reviewers consistently praise the long battery life, stating it lasts "hours of uninterrupted music," "a full day of listening," and "the whole afternoon." The feature that announces the remaining battery percentage is also appreciated.
#
#
# **2. What Customers Love Most About This Product:**
#
# Customers overwhelmingly love the combination of surprisingly high-quality sound, impressive durability for its size and portability, and long battery life.  The value for the price is also frequently cited.  Specific examples include:
#
# * "Price, sound quality, connectibility and control. All for under $75."
# * "portable and durable with decent sound"
# * "incredible punch, delivering rich, clear sound and deep bass"
# * "rugged, waterproof design"
# * "excellent, providing hours of uninterrupted music"
# *  "The bass surprised me the most...It’s not going to shake the windows, but you can feel it."
# * "I dropped it once...but it didn’t break."
#
#
# **3. Most Common Complaints:**
#
# The most common complaint is the lack of true voice activation. While compatible with Google Assistant and Alexa, it requires a button press to initiate voice commands, which some find cumbersome.  One reviewer explicitly states: "My only complaint is that I wish it was voice activated...I found that to be a bit cumbersome."
#
# Another minor complaint is occasional connectivity issues, though these seem easily resolved by restarting the speaker. One reviewer notes: "One time it didn’t connect right to my phone, but turning it off and on fixed that."
#
# There are no other significant recurring complaints.  The few minor issues mentioned are not widespread and are generally considered minor inconveniences that do not detract significantly from the overall positive experience.

# %%
def analyze_sentiment_patterns(reviews, sentiment_category, product_name):
    prompt_message = f"""Analyze these {sentiment_category.lower()} reviews for {product_name}:
    1. What specific aspects create {sentiment_category.lower()} reactions?
    2. Identify common phrases or descriptions used
    3. Note any comparisons with competitor products
    4. Find unexpected or unique feedback

    Support your analysis with specific examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze positive reviews for a product
positive_reviews = df[
    (df['short_name'] == 'Bose SoundLink Flex Speaker') &
    (df['sentiment_category'] == 'Positive')
]['content'].tolist()[:30]

positive_insights = analyze_sentiment_patterns(
    positive_reviews,
    'Positive',
    'Bose SoundLink Flex Speaker'
)
print(positive_insights)
# Out:
# Analysis of Positive Bose SoundLink Flex Speaker Reviews:
#
# **1. Specific Aspects Creating Positive Reactions:**
#
# * **Sound Quality:**  Reviewers consistently praise the surprisingly good sound quality for such a small and portable speaker.  Specific mentions include "rich, clear sound," "deep bass," "crisp highs," and the ability to "fill any space," even outdoors. The bass, in particular, is frequently highlighted as exceeding expectations.  (Review 3, 4, 6)
#
# * **Portability and Durability:** The speaker's compact size, rugged design, and water/dust resistance (IP67 rating) are major selling points.  Reviewers appreciate its suitability for outdoor use, travel, and various activities like camping, hiking, and working in a garage. (Review 2, 3, 4, 6)
#
# * **Ease of Use and Connectivity:**  The simple setup, fast and reliable Bluetooth pairing, and intuitive controls are repeatedly mentioned as positive aspects. The clear battery level announcements are also appreciated. (Review 1, 2, 5, 6)
#
# * **Battery Life:**  The long battery life is frequently cited, often described as lasting "hours" or "a full day" of use. (Review 3, 4, 5)
#
# * **Value for Money:** Many reviewers emphasize the speaker's excellent value, especially considering its price point, often stating it's "worth every penny" or "exactly what I wanted for the price." (Review 1, 2, 5, 6)
#
# * **PositionIQ Technology (Review 6):** This advanced feature, which automatically adjusts sound based on speaker orientation, is a unique selling point that impressed at least one reviewer.
#
# **2. Common Phrases and Descriptions:**
#
# * "Great sound quality" or variations thereof
# * "Portable and durable"
# * "Easy to use"
# * "Excellent battery life"
# * "Water and dust resistant"
# * "Surprisingly good bass"
# * "Fills the room/space"
# * "Highly recommend"
# * "Worth the price/money"
#
#
# **3. Comparisons with Competitor Products:**
#
# There are no direct comparisons to specific competitor products by name. However, review 2 implicitly compares the SoundLink Flex favorably to other Bluetooth speakers on the market, suggesting that despite the availability of many options, this one stands out due to its value and features.  Review 5 explicitly compares the SoundLink Flex to a previous generation Bose speaker, highlighting improvements in battery life, charging port design, and the ability to sync two speakers.
#
# **4. Unexpected or Unique Feedback:**
#
# * The relatively minor complaint in review 2 about the lack of true voice activation (requiring a button press to engage Google Assistant or Alexa) is noteworthy because it highlights the limitations despite the generally overwhelmingly positive experience.  The reviewer ultimately decides it isn't a deal-breaker.
#
# * The mention in review 6 of the PositionIQ technology stands out as a unique feature that sets this speaker apart from others in a compelling way.  This detail goes beyond the standard positive comments about sound quality and durability.
#
# * Review 4's unexpected positive aspect is the speaker's durability after being dropped and exposed to dirt and water, exceeding initial expectations.  This reflects the value of the rugged build quality.
#
# In summary, the positive reviews strongly emphasize the Bose SoundLink Flex's exceptional sound quality for its size, impressive portability and durability, ease of use, and excellent value for the price.  The unexpected durability and unique PositionIQ technology add further to its appeal.

# %%
def analyze_comparative_reviews(reviews_dict):
    # Combine all product names for the prompt
    products_list = ", ".join(reviews_dict.keys())

    prompt_message = f"""Compare customer feedback across these products: {products_list}

    For each product, analyze:
    1. Standout features and unique selling points
    2. Common complaints or limitations
    3. Price-to-value perception
    4. Target user preferences

    Then compare:
    1. Key differences in customer satisfaction
    2. Feature preferences across products
    3. Quality and reliability mentions

    Format as a structured comparison with specific examples."""

    # Combine reviews with product labels
    combined_reviews = []
    for product, reviews in reviews_dict.items():
        labeled_reviews = [f"[{product}] {review}" for review in reviews]
        combined_reviews.extend(labeled_reviews[:20])  # Take first 20 reviews per product

    return analyze_reviews(combined_reviews, api_key, prompt_message)

# %%
# Example: Compare two products
products_to_compare = ['Bose SoundLink Flex Speaker', 'Beats Pill']
reviews_dict = {}
for product in products_to_compare:
    reviews = df[df['short_name'] == product]['content'].tolist()[:20]
    reviews_dict[product] = reviews

comparison_insights = analyze_comparative_reviews(reviews_dict)
print(comparison_insights)
# Out:
# ## Bose SoundLink Flex vs. Beats Pill: A Customer Feedback Comparison
#
# This comparison analyzes customer feedback on the Bose SoundLink Flex and Beats Pill portable Bluetooth speakers.
#
# **1. Bose SoundLink Flex:**
#
# * **Standout Features & Unique Selling Points:**
#     * **Durability and Water Resistance:**  Consistently praised for its rugged build, IP67 rating (dust and water resistance), and ability to withstand drops and harsh environments. Users highlighted its suitability for outdoor use, camping, and travel.
#     * **Sound Quality for Size:**  Many reviewers were surprised by the rich, clear sound and surprisingly deep bass for such a compact speaker.  The PositionIQ technology, automatically adjusting sound based on orientation, was also a positive highlight.
#     * **Battery Life:**  Users reported excellent battery life, lasting through a full day of use in many cases.  Real-time battery level updates were also appreciated.
#     * **Ease of Use:** Setup was described as simple and straightforward, with reliable Bluetooth pairing.
#
#
# * **Common Complaints/Limitations:**
#     * **Lack of Voice Assistant Integration:** While compatible with Google Assistant and Alexa, the need to physically press a button to activate them was a recurring minor complaint.
#
#
# * **Price-to-Value Perception:**  Generally perceived as offering excellent value for its price, particularly given its sound quality, durability, and features.  Several users specifically mentioned finding it at a discounted price which further enhanced the value.
#
#
# * **Target User Preferences:** Users who value durability, portability, good sound quality in a compact package, and water resistance are the ideal target audience. This includes individuals who enjoy outdoor activities, travel, or simply want a robust speaker for various environments.
#
#
# **2. Beats Pill:**
#
# * **Standout Features & Unique Selling Points:**
#     * **Sound Quality & Bass:**  Praised for its powerful and clear sound, with a particularly strong bass response.  Many users found the sound to be superior to other speakers in its class.
#     * **Portability (despite size increase):** While some users were disappointed by the increased size compared to previous models, the overall feedback still indicates good portability for its class, however larger than previous iterations.
#     * **Lossless Listening:** The option to connect via wired connection (not Bluetooth) was a significant positive for some users concerned about Bluetooth interference or preferring higher quality audio through a direct connection.
#
#
# * **Common Complaints/Limitations:**
#     * **Size Discrepancy:** A major complaint revolved around the larger size compared to previous Beats Pill models, which deviated from user expectations based on product images.
#     * **Bluetooth Connectivity Issues:** Several reviews mentioned intermittent Bluetooth disconnections, requiring re-pairing.
#     * **Loud On/Off Sounds:** The relatively loud sound emitted during power on/off was noted as a minor annoyance by some.
#
#
# * **Price-to-Value Perception:** Generally considered a good value, especially when purchased on sale.  Some reviewers highlighted its competitive pricing compared to similar speakers from other brands.
#
#
# * **Target User Preferences:**  Users who prioritize strong bass, clear sound quality, a smaller form-factor, lossless wired audio connection options, and Apple device integration would likely appreciate this speaker.
#
#
# **Comparison:**
#
# * **Key Differences in Customer Satisfaction:** Bose SoundLink Flex receives consistently high praise for its durability and water resistance, exceeding user expectations in this area. Beats Pill receives higher praise for its raw sound quality and bass response, but suffers from more negative feedback surrounding Bluetooth connectivity and the increased size from previous models.
#
#
# * **Feature Preferences Across Products:**  Users favoured Bose SoundLink Flex for its ruggedness and water resistance, vital for outdoor use.  Beats Pill users favored its powerful sound, particularly the bass, and the option of lossless wired connection.
#
#
# * **Quality and Reliability Mentions:** While both speakers generally receive positive feedback regarding sound quality, the Bose SoundLink Flex demonstrates greater reliability and build quality in customer reviews.  The Beats Pill experiences more complaints concerning inconsistent Bluetooth performance and the unexpected size increase.
#
# **Conclusion:**
#
# Both speakers offer excellent sound for their size, but cater to slightly different needs.  The Bose SoundLink Flex is the more robust and versatile choice for outdoor enthusiasts and users prioritizing durability and water resistance. The Beats Pill, while potentially having superior sound characteristics, suffers from some consistency issues, and its larger size may not be suitable for all users.  The choice depends heavily on individual priorities: ruggedness vs. pure audio performance.

# %%
def analyze_feature(reviews, feature_name):
    prompt_message = f"""Analyze mentions of {feature_name} in these reviews:
    1. How do customers describe the {feature_name}?
    2. What specific aspects are praised or criticized?
    3. How does {feature_name} compare across products?
    4. What improvements do customers suggest?

    Include specific quotes and examples."""

    return analyze_reviews(reviews, api_key, prompt_message)

# %%
# Example: Analyze battery life mentions
battery_reviews = df[
    df['content'].str.contains('battery|charge|power', case=False, na=False)
]['content'].tolist()[:200]

battery_insights = analyze_feature(battery_reviews, "battery life")
print(battery_insights)
# Out:
# Here's an analysis of battery life mentions in the provided reviews:
#
# **1. How do customers describe the battery life?**
#
# Customers use a variety of terms to describe battery life, ranging from highly positive to neutral or slightly negative:
#
# * **Positive:** "excellent," "hours of uninterrupted music," "easily lasting through a full day of listening," "lasts the whole afternoon," "many hours," "12 hours of playtime," "long enough to ensure continuous play for multiple 4-6 hour days," "whole camping trip," "goes for hours of music on a single charge," "outstanding, lasting hours on a single charge."
#
# * **Neutral:** "decent," "good enough for me," "average."
#
# * **Negative:** "isn’t very long anymore" (referring to an older model), "seems good...not sure if the battery lasts the full 12 hours as stated."  One review mentions that battery life is shortened if certain features (lights and bass boost) are used.
#
#
# **2. What specific aspects are praised or criticized?**
#
# * **Praise:**  Many reviews praise the long battery life, especially in the context of outdoor use or all-day listening.  The provision of battery level updates (either verbally upon power-on or visually) is also appreciated.
#
# * **Criticism:** The main criticism centers around the lack of precise or continuous battery level indicators during playback.  One review notes that some speakers' battery life is not as advertised if extra features like lights or bass boost are used. Another mentions inconsistent battery performance in an older model.  In one case, a reviewer found the battery indicator design inadequate, showing only a line until nearing depletion.
#
#
# **3. How does battery life compare across products?**
#
# Direct comparisons are limited, but some reviews offer implicit comparisons:
#
# * The reviewer comparing the Bose Soundlink Flex to their older Soundlink notes a significant drop-off in battery performance in the older model.
#
# * Several reviews mention the 12-hour battery life of the JBL Flip 6 and Sony ULT Field 1 as a key selling point, implying this is a desirable benchmark.
#
# * The Beats Pill is advertised as having "up to 24H battery life," but this claim is not explicitly verified in reviews.
#
#
# **4. What improvements do customers suggest?**
#
# The primary suggestion for improvement revolves around the battery indicator:  Reviewers want a more precise and consistently visible battery level indicator during playback, rather than just at power on/off.  Some users also want clearer labeling or awareness on how certain features affect battery life.
