# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiyeoba-1/Projects/blob/main/JSON_reviews_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

# %%
file_path = '/content/data_2.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_2.csv', index=False)
reviews_df
# Out:
#          review_id  product_id  \
# 0   R1AEL2WD0Y69DS  B0BYC52LYP
# 1   R13HQG5XTEW55Q  B0BYC52LYP
# 2   R3E563Z02CE6N9  B0BYC52LYP
# 3   R1DME16K25CY2G  B0BYC52LYP
# 4   R256FAIVE5YJGD  B0BYC52LYP
# ..             ...         ...
# 75  R1DME16K25CY2G  B0BYC52LYP
# 76  R256FAIVE5YJGD  B0BYC52LYP
# 77   REUN9NLPQWGTA  B0BYC52LYP
# 78  R2M1K8MTJUBGI5  B0BYC52LYP
# 79    RWNXFB87I0SH  B0BYC52LYP
#
#                                                 title             author  \
# 0   5.0 out of 5 stars Ultimate Ears best portable...          J. Bowman
# 1          5.0 out of 5 stars Perfect little speaker!  Curlyhead Shinobi
# 2   5.0 out of 5 stars The Ultimate Bluetooth Spea...       Nelson Lista
# 3              5.0 out of 5 stars Best speaker I have       GoForBrandon
# 4         4.0 out of 5 stars loud but not loud enough      michael clark
# ..                                                ...                ...
# ...

# %%
len(reviews_df)
# Out:
# 30

# %%
df_1 = pd.read_csv('/content/reviews_1.csv')
df_2 = pd.read_csv('/content/reviews_2.csv')
df_3 = pd.read_csv('/content/reviews_3.csv')
df_4 = pd.read_csv('/content/reviews_4.csv')
df_5 = pd.read_csv('/content/reviews_5.csv')
df_6 = pd.read_csv('/content/reviews_6.csv')
df_7 = pd.read_csv('/content/reviews_7.csv')
df_8 = pd.read_csv('/content/reviews_8.csv')

df_2.head()
# Out:
#         review_id  product_id  \
# 0  R1AEL2WD0Y69DS  B0BYC52LYP
# 1  R13HQG5XTEW55Q  B0BYC52LYP
# 2  R3E563Z02CE6N9  B0BYC52LYP
# 3  R1DME16K25CY2G  B0BYC52LYP
# 4  R256FAIVE5YJGD  B0BYC52LYP
#
#                                                title             author  \
# 0  5.0 out of 5 stars Ultimate Ears best portable...          J. Bowman
# 1         5.0 out of 5 stars Perfect little speaker!  Curlyhead Shinobi
# 2  5.0 out of 5 stars The Ultimate Bluetooth Spea...       Nelson Lista
# 3             5.0 out of 5 stars Best speaker I have       GoForBrandon
# 4        4.0 out of 5 stars loud but not loud enough      michael clark
#
#    rating                                            content  \
# 0       5  I recently got my hands on the Ultimate Ears E...
# 1       5  This is my second ultimate ear speaker. I have...
# 2       5  I'm blown away by my Ultimate Ears EVERBOOM. I...
# 3       5  The speaker blows me away, put it in the middl...
# ...

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7,df_8], ignore_index=True)
merged_df
# Out:
#           review_id  product_id  \
# 0    R1TIU27G892G8N  B09GJVTRNZ
# 1    R3UHPD69SUVF4D  B09GJVTRNZ
# 2     R8ZPP4M7T18BO  B09GJVTRNZ
# 3    R3T9HSXO492VDG  B09GJVTRNZ
# 4     RF4X9MUCFL4QZ  B09GJVTRNZ
# ..              ...         ...
# 408  R1DME16K25CY2G  B0BYC52LYP
# 409  R256FAIVE5YJGD  B0BYC52LYP
# 410   REUN9NLPQWGTA  B0BYC52LYP
# 411  R2M1K8MTJUBGI5  B0BYC52LYP
# 412    RWNXFB87I0SH  B0BYC52LYP
#
#                                                  title  \
# 0    5.0 out of 5 stars Best for modern music; fine...
# 1    5.0 out of 5 stars Incredible Sound and Perfor...
# 2                5.0 out of 5 stars The Sound Is Great
# 3    5.0 out of 5 stars Incredible Sound and Durabi...
# 4         5.0 out of 5 stars Not too small Not too big
# ..                                                 ...
# 408             5.0 out of 5 stars Best speaker I have
# 409        4.0 out of 5 stars loud but not loud enough
# 410              5.0 out of 5 stars Daughter loves it!
# ...

# %%
merged_df.to_csv('merged_data.csv', index=False)

# %%
check_df = pd.read_csv('/content/reference_dataset_for_beats_externship.csv')
check_df
# Out:
#       Unnamed: 0       review_id  product_id  \
# 0              0   RUE030N50F9EJ  B09PYVXXW5
# 1              1  R385JSD6KWP2QU  B09PYVXXW5
# 2              2  R1UB1V4EPP9MN3  B09PYVXXW5
# 3              3   RWYK1GXIVV6H1  B09PYVXXW5
# 4              4  R3FBQBGQM3II4W  B09PYVXXW5
# ...          ...             ...         ...
# 4940        5865  R2YE8KKVZGETCW  B0CY6S748H
# 4941        5889   RERGCQ3PLJUTJ  B0CY6S748H
# 4942        5890  R25VEKRF5EV836  B0CY6S748H
# 4943        5891  R34PNR72XAULLC  B0CY6S748H
# 4944        5892  R1GHYH6N4V9BRB  B0CY6S748H
#
#                                                   title       author  rating  \
# 0     5.0 out of 5 stars Really good with a couple o...          CTM       5
# 1     4.0 out of 5 stars I wish I could rate 5 stars...       Gianna       4
# 2     5.0 out of 5 stars Basically perfect, fantasti...     Colin M.       5
# 3               1.0 out of 5 stars Decent but Defective       Aquila       1
# ...

# %%
check_df = check_df.drop('Unnamed: 0', axis=1)
check_df
# Out:
#            review_id  product_id  \
# 0      RUE030N50F9EJ  B09PYVXXW5
# 1     R385JSD6KWP2QU  B09PYVXXW5
# 2     R1UB1V4EPP9MN3  B09PYVXXW5
# 3      RWYK1GXIVV6H1  B09PYVXXW5
# 4     R3FBQBGQM3II4W  B09PYVXXW5
# ...              ...         ...
# 4940  R2YE8KKVZGETCW  B0CY6S748H
# 4941   RERGCQ3PLJUTJ  B0CY6S748H
# 4942  R25VEKRF5EV836  B0CY6S748H
# 4943  R34PNR72XAULLC  B0CY6S748H
# 4944  R1GHYH6N4V9BRB  B0CY6S748H
#
#                                                   title       author  rating  \
# 0     5.0 out of 5 stars Really good with a couple o...          CTM       5
# 1     4.0 out of 5 stars I wish I could rate 5 stars...       Gianna       4
# 2     5.0 out of 5 stars Basically perfect, fantasti...     Colin M.       5
# 3               1.0 out of 5 stars Decent but Defective       Aquila       1
# 4      3.0 out of 5 stars I went with soundcore instead      Frankie       3
# ...                                                 ...          ...     ...
# ...

# %%
check_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
merged_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %%
merged_df = pd.concat([merged_df,check_df], ignore_index=True)
merged_df
# Out:
#            review_id  product_id  \
# 0     R1TIU27G892G8N  B09GJVTRNZ
# 1     R3UHPD69SUVF4D  B09GJVTRNZ
# 2      R8ZPP4M7T18BO  B09GJVTRNZ
# 3     R3T9HSXO492VDG  B09GJVTRNZ
# 4      RF4X9MUCFL4QZ  B09GJVTRNZ
# ...              ...         ...
# 5353  R2YE8KKVZGETCW  B0CY6S748H
# 5354   RERGCQ3PLJUTJ  B0CY6S748H
# 5355  R25VEKRF5EV836  B0CY6S748H
# 5356  R34PNR72XAULLC  B0CY6S748H
# 5357  R1GHYH6N4V9BRB  B0CY6S748H
#
#                                                   title  \
# 0     5.0 out of 5 stars Best for modern music; fine...
# 1     5.0 out of 5 stars Incredible Sound and Perfor...
# 2                 5.0 out of 5 stars The Sound Is Great
# 3     5.0 out of 5 stars Incredible Sound and Durabi...
# 4          5.0 out of 5 stars Not too small Not too big
# ...                                                 ...
# 5353                 4.0 out of 5 stars Quality speaker
# 5354  1.0 out of 5 stars Buyer beware WiFi connectio...
# ...

# %%
merged_df = merged_df.drop_duplicates()
merged_df
# Out:
#            review_id  product_id  \
# 0     R1TIU27G892G8N  B09GJVTRNZ
# 1     R3UHPD69SUVF4D  B09GJVTRNZ
# 2      R8ZPP4M7T18BO  B09GJVTRNZ
# 3     R3T9HSXO492VDG  B09GJVTRNZ
# 4      RF4X9MUCFL4QZ  B09GJVTRNZ
# ...              ...         ...
# 5353  R2YE8KKVZGETCW  B0CY6S748H
# 5354   RERGCQ3PLJUTJ  B0CY6S748H
# 5355  R25VEKRF5EV836  B0CY6S748H
# 5356  R34PNR72XAULLC  B0CY6S748H
# 5357  R1GHYH6N4V9BRB  B0CY6S748H
#
#                                                   title  \
# 0     5.0 out of 5 stars Best for modern music; fine...
# 1     5.0 out of 5 stars Incredible Sound and Perfor...
# 2                 5.0 out of 5 stars The Sound Is Great
# 3     5.0 out of 5 stars Incredible Sound and Durabi...
# 4          5.0 out of 5 stars Not too small Not too big
# ...                                                 ...
# 5353                 4.0 out of 5 stars Quality speaker
# 5354  1.0 out of 5 stars Buyer beware WiFi connectio...
# ...

# %%
merged_df.to_csv('new_reference_data_for_beats.csv', index=False)
